# %% [markdown]
# Example markdown cell

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.normal(0, 1, 100)

# %%
plt.scatter(x, x ** 3)

# %%
#@ title Solution
with plt.xkcd():
    plt.scatter(x, x ** 3)
