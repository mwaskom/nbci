# %% [markdown]
# # Example notebook
#
# Example markdown cell

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.normal(0, 1, 100)

# %%
y = x ** 2
plt.scatter(x, y)

# %%
# to_remove solution
y = x ** 2
with plt.xkcd():
    plt.scatter(x, y)
