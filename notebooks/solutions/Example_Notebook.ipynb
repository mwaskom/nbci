# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.normal(0, 1, 100)

# %%
plt.scatter(x, x ** 3)

# %%
#@title Solution
with plt.xkcd():
    plt.scatter(x, x ** 3)
# Out:
# /opt/hostedtoolcache/Python/3.7.7/x64/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
